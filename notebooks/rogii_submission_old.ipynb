# %% [markdown]
# # Rogii Submission (Legacy)
# This notebook reproduces the original EXP‑007b pipeline using the original `scratch/run_exp007b.py` script.

# %%
# Run the original script
# %run ../../scratch/run_exp007b.py
